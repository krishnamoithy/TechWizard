# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('hari.csv')
gender_counts = data['2.Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index,
        autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Male and Female Distribution')
plt.show()

# %%
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Calculate total count
total_count = len(data)

# Calculate branch-wise counts
branch_counts = data['4. Branch'].value_counts()

# Plot branch-wise counts
plt.figure(figsize=(8, 6))
branch_counts.plot(kind='bar')
plt.title('Branch-wise Counts')
plt.xlabel('Branch')
plt.ylabel('Count')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named 'School_Type'
# Replace 'School_Type' with your actual column name
schooling_counts = data['1. Type of Schooling till 10th Grade:'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(schooling_counts, labels=schooling_counts.index,
        autopct='%1.1f%%', startangle=140)
plt.title('Types of Schooling till 10th Grade')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named 'School_Type'
# Replace 'School_Type' with your actual column name
schooling_counts = data['4. Type of Schooling for class 12th:'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(schooling_counts, labels=schooling_counts.index,
        autopct='%1.1f%%', startangle=140)
plt.title('Types of Schooling till 12th Grade')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named '2. Percentage in Class 10th?'
# Replace '2. Percentage in Class 10th?' with your actual column name
schooling_counts = data['2. Percentage in Class 10th?'].value_counts()

# Define colors for each bar (you can add more colors if needed)
colors = ['skyblue', 'salmon', 'lightgreen', 'orange', 'yellow', 'purple']

# Plot a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
schooling_counts.plot(kind='bar', color=colors)
plt.xlabel(' Percentage in Class 10th')
plt.ylabel('Count')
plt.title(' Percentage in Class 10th')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named '2. Percentage in Class 10th?'
# Replace '2. Percentage in Class 10th?' with your actual column name
schooling_counts = data['5. Percentage in Class 12th?'].value_counts()

# Define colors for each bar (you can add more colors if needed)
colors = ['skyblue', 'salmon', 'lightgreen', 'orange', 'yellow', 'purple']

# Plot a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
schooling_counts.plot(kind='bar', color=colors)
plt.xlabel(' Percentage in Class 12th')
plt.ylabel('Count')
plt.title(' Percentage in Class 12th')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named '3. Location of Class 10th School:'
# Replace '3. Location of Class 10th School:' with your actual column name
schooling_counts = data['3. Location of Class 10th School:'].value_counts()

# Get unique locations and define colors for each unique location
unique_locations = schooling_counts.index
num_colors = len(unique_locations)
# Using a colormap to generate distinct colors
colors = plt.cm.tab10(range(num_colors))

# Plot a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
schooling_counts.plot(kind='bar', color=colors)
plt.xlabel('Location of Class 10th School')
plt.ylabel('Count')
plt.title('Location of Class 10th School')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing schooling information is named '3. Location of Class 10th School:'
# Replace '3. Location of Class 10th School:' with your actual column name
schooling_counts = data['6. Location of Class 12th School:'].value_counts()

# Get unique locations and define colors for each unique location
unique_locations = schooling_counts.index
num_colors = len(unique_locations)
# Using a colormap to generate distinct colors
colors = plt.cm.tab10(range(num_colors))

# Plot a bar chart with different colors for each bar
plt.figure(figsize=(10, 6))
schooling_counts.plot(kind='bar', color=colors)
plt.xlabel('Location of Class 12th School')
plt.ylabel('Count')
plt.title('Location of Class 12th School')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing 'Dropped an year after School?' is named '7. Dropped an year after School?'
# Replace '7. Dropped an year after School?' with your actual column name
schooling_counts = data['7. Dropped an year after School?'].value_counts()

# Get unique categories and define colors for each category
unique_categories = schooling_counts.index
num_colors = len(unique_categories)
colors = plt.cm.tab10(range(num_colors))

# Plot a donut chart with different colors for each category
plt.figure(figsize=(8, 8))

# Create the donut chart using pie chart with a wedgeprops parameter to turn it into a donut
plt.pie(schooling_counts, labels=unique_categories, colors=colors,
        autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))

# Draw a circle in the middle to make it a donut chart
centre_circle = plt.Circle((0, 0), 0.6, color='white',
                           fc='white', linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Dropped an Year after School')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing 'Actively involved in Specific technology?' is named '2. Actively involved in Specific technology?'
# Replace '2. Actively involved in Specific technology?' with your actual column name
technology_counts = data['2.  Actively involved in Specific technology?'].value_counts()

# Get unique categories and define colors for each category
unique_categories = technology_counts.index
num_colors = len(unique_categories)
colors = plt.cm.tab10(range(num_colors))

# Plot a bar chart with different colors for each category
plt.figure(figsize=(10, 6))
technology_counts.plot(kind='bar', color=colors)
plt.xlabel('Actively Involved in Specific Technology')
plt.ylabel('Count')
plt.title('Distribution of Actively Involved in Specific Technology')
plt.show()

# %%
# Read the CSV file
file_path = 'hari.csv'  # Replace 'your_file.csv' with the actual file path
data = pd.read_csv(file_path)

# Assuming the column containing 'Have you made any Software based projects?' is named '8. Have you made any Software based projects?'
# Replace '8. Have you made any Software based projects?' with your actual column name
projects_counts = data['8. Have you made any Software based projects?'].value_counts()

# Get unique categories and define colors for each category
unique_categories = projects_counts.index
num_colors = len(unique_categories)
colors = plt.cm.tab10(range(num_colors))

# Plot a pie chart with different colors for each category
plt.figure(figsize=(8, 8))
plt.pie(projects_counts, labels=unique_categories,
        colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Software based Projects')
plt.show()
